# %%
import pandas as pd

# %%
df = pd.read_csv("D:\\Data Sets☠️💀\\Foodpanda Analysis Dataset.csv")

# %%
df.head()
# Out:
#   customer_id  gender     age      city signup_date order_id order_date  \
# 0       C5663    Male   Adult  Peshawar   1/14/2024    O9663  8/23/2023
# 1       C2831    Male   Adult    Multan    7/7/2024    O6831  8/23/2023
# 2       C2851   Other  Senior    Multan   6/20/2025    O6851  8/23/2023
# 3       C1694  Female  Senior  Peshawar    9/5/2023    O5694  8/23/2023
# 4       C4339   Other  Senior    Lahore  12/29/2023    O8339  8/24/2023
#
#   restaurant_name dish_name category  quantity    price payment_method  \
# 0      McDonald's    Burger  Italian         5  1478.27           Cash
# 1             KFC    Burger  Italian         3   956.04         Wallet
# 2       Pizza Hut     Fries  Italian         2   882.51           Cash
# 3          Subway     Pizza  Dessert         4   231.30           Card
# 4             KFC  Sandwich  Dessert         1  1156.69           Cash
#
#    order_frequency last_order_date  loyalty_points   churned  rating  \
# ...

# %%
df.describe()
# Out:
#           quantity        price  order_frequency  loyalty_points       rating
# count  6000.000000  6000.000000      6000.000000     6000.000000  6000.000000
# mean      2.991667   800.524880        25.304667      250.173667     2.996833
# std       1.414778   404.855029        14.358930      144.608478     1.406113
# min       1.000000   100.300000         1.000000        0.000000     1.000000
# 25%       2.000000   441.997500        13.000000      125.000000     2.000000
# 50%       3.000000   806.460000        25.000000      249.500000     3.000000
# 75%       4.000000  1149.737500        37.000000      378.000000     4.000000
# max       5.000000  1499.950000        50.000000      500.000000     5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      6000 non-null   object
#  1   gender           6000 non-null   object
#  2   age              6000 non-null   object
#  3   city             6000 non-null   object
#  4   signup_date      6000 non-null   object
#  5   order_id         6000 non-null   object
#  6   order_date       6000 non-null   object
#  7   restaurant_name  6000 non-null   object
#  8   dish_name        6000 non-null   object
#  9   category         6000 non-null   object
#  10  quantity         6000 non-null   int64
#  11  price            6000 non-null   float64
#  12  payment_method   6000 non-null   object
#  13  order_frequency  6000 non-null   int64
#  14  last_order_date  6000 non-null   object
#  15  loyalty_points   6000 non-null   int64
# ...

# %%
df['city']
# Out:
# 0        Peshawar
# 1          Multan
# 2          Multan
# 3        Peshawar
# 4          Lahore
#           ...
# 5995       Multan
# 5996    Islamabad
# 5997    Islamabad
# 5998    Islamabad
# 5999       Multan
# Name: city, Length: 6000, dtype: object

# %%
type(df['age'][3])
# Out:
# str

# %%
df[['restaurant_name','dish_name','city']]
# Out:
#      restaurant_name dish_name       city
# 0         McDonald's    Burger   Peshawar
# 1                KFC    Burger     Multan
# 2          Pizza Hut     Fries     Multan
# 3             Subway     Pizza   Peshawar
# 4                KFC  Sandwich     Lahore
# ...              ...       ...        ...
# 5995       Pizza Hut    Burger     Multan
# 5996             KFC     Pizza  Islamabad
# 5997             KFC  Sandwich  Islamabad
# 5998             KFC     Fries  Islamabad
# 5999     Burger King     Fries     Multan
#
# [6000 rows x 3 columns]

# %%
df.loc[8, 'city']
# Out:
# 'Karachi'

# %%
df.iloc[8,3]
# Out:
# 'Karachi'

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'signup_date', 'order_id',
#        'order_date', 'restaurant_name', 'dish_name', 'category', 'quantity',
#        'price', 'payment_method', 'order_frequency', 'last_order_date',
#        'loyalty_points', 'churned', 'rating', 'rating_date',
#        'delivery_status'],
#       dtype='object')

# %%
df.loc[2:5,['city','restaurant_name','dish_name','delivery_status']]
# Out:
#        city restaurant_name dish_name delivery_status
# 2    Multan       Pizza Hut     Fries         Delayed
# 3  Peshawar          Subway     Pizza         Delayed
# 4    Lahore             KFC  Sandwich       Cancelled
# 5   Karachi     Burger King     Pizza       Delivered

# %%
df.iloc[2:6,[3,7,8,19]]
# Out:
#        city restaurant_name dish_name delivery_status
# 2    Multan       Pizza Hut     Fries         Delayed
# 3  Peshawar          Subway     Pizza         Delayed
# 4    Lahore             KFC  Sandwich       Cancelled
# 5   Karachi     Burger King     Pizza       Delivered

# %%
df.at[2,'city']
# Out:
# 'Multan'

# %%
df.iat[2,3]
# Out:
# 'Multan'

# %%
df[df['quantity']> 4]
# Out:
#      customer_id  gender       age       city signup_date order_id order_date  \
# 0          C5663    Male     Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 5          C6543   Other     Adult    Karachi   9/28/2023   O10543  8/24/2023
# 6          C6423    Male     Adult     Lahore    4/8/2025   O10423  8/24/2023
# 8          C5146   Other    Senior    Karachi  12/17/2024    O9146  8/24/2023
# 23         C5497   Other     Adult     Lahore   1/26/2025    O9497  8/25/2023
# ...          ...     ...       ...        ...         ...      ...        ...
# 5971       C2798  Female  Teenager     Multan   8/25/2024    O6798  8/19/2025
# 5986       C2893    Male     Adult     Multan   8/13/2024    O6893  8/21/2025
# 5987       C4048    Male  Teenager     Lahore  10/16/2023    O8048  8/21/2025
# 5990       C3236  Female    Senior   Peshawar   7/18/2025    O7236  8/21/2025
# 5996       C3787  Female     Adult  Islamabad   1/28/2025    O7787  8/22/2025
#
# ...

# %%
df[df["quantity"]> 4]['city']
# Out:
# 0        Peshawar
# 5         Karachi
# 6          Lahore
# 8         Karachi
# 23         Lahore
#           ...
# 5971       Multan
# 5986       Multan
# 5987       Lahore
# 5990     Peshawar
# 5996    Islamabad
# Name: city, Length: 1208, dtype: object

# %%
df[(df['quantity'] > 4) & (df['rating'] > 4)]
# Out:
#      customer_id  gender       age       city signup_date order_id order_date  \
# 29         C5795  Female    Senior  Islamabad   11/7/2023    O9795  8/26/2023
# 82         C5566   Other  Teenager  Islamabad   3/25/2024    O9566   9/1/2023
# 140        C3815    Male  Teenager    Karachi    4/7/2025    O7815   9/9/2023
# 164        C6753   Other  Teenager     Multan   8/24/2024   O10753  9/11/2023
# 193        C1905  Female    Senior     Multan    2/8/2025    O5905  9/14/2023
# ...          ...     ...       ...        ...         ...      ...        ...
# 5854       C3964   Other  Teenager    Karachi   9/21/2023    O7964   8/5/2025
# 5855       C4522  Female     Adult  Islamabad   4/24/2025    O8522   8/6/2025
# 5880       C1064    Male     Adult     Multan  10/13/2023    O5064   8/8/2025
# 5971       C2798  Female  Teenager     Multan   8/25/2024    O6798  8/19/2025
# 5986       C2893    Male     Adult     Multan   8/13/2024    O6893  8/21/2025
#
# ...

# %%
df.query('quantity > 4 and rating > 4')
# Out:
#      customer_id  gender       age       city signup_date order_id order_date  \
# 29         C5795  Female    Senior  Islamabad   11/7/2023    O9795  8/26/2023
# 82         C5566   Other  Teenager  Islamabad   3/25/2024    O9566   9/1/2023
# 140        C3815    Male  Teenager    Karachi    4/7/2025    O7815   9/9/2023
# 164        C6753   Other  Teenager     Multan   8/24/2024   O10753  9/11/2023
# 193        C1905  Female    Senior     Multan    2/8/2025    O5905  9/14/2023
# ...          ...     ...       ...        ...         ...      ...        ...
# 5854       C3964   Other  Teenager    Karachi   9/21/2023    O7964   8/5/2025
# 5855       C4522  Female     Adult  Islamabad   4/24/2025    O8522   8/6/2025
# 5880       C1064    Male     Adult     Multan  10/13/2023    O5064   8/8/2025
# 5971       C2798  Female  Teenager     Multan   8/25/2024    O6798  8/19/2025
# 5986       C2893    Male     Adult     Multan   8/13/2024    O6893  8/21/2025
#
# ...

# %%
# Map age categories to numeric values
age_map = {'Teenager': 13, 'Adult': 25, 'Senior': 65}
df['age_num'] = df['age'].map(age_map)

# Filter using the numeric age
df[(df['age_num'] > 15) & (df['quantity'] > 4)]
# Out:
#      customer_id  gender     age       city signup_date order_id order_date  \
# 0          C5663    Male   Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 5          C6543   Other   Adult    Karachi   9/28/2023   O10543  8/24/2023
# 6          C6423    Male   Adult     Lahore    4/8/2025   O10423  8/24/2023
# 8          C5146   Other  Senior    Karachi  12/17/2024    O9146  8/24/2023
# 23         C5497   Other   Adult     Lahore   1/26/2025    O9497  8/25/2023
# ...          ...     ...     ...        ...         ...      ...        ...
# 5935       C2957  Female   Adult  Islamabad    8/1/2025    O6957  8/14/2025
# 5948       C1241   Other   Adult     Multan   3/16/2025    O5241  8/15/2025
# 5986       C2893    Male   Adult     Multan   8/13/2024    O6893  8/21/2025
# 5990       C3236  Female  Senior   Peshawar   7/18/2025    O7236  8/21/2025
# 5996       C3787  Female   Adult  Islamabad   1/28/2025    O7787  8/22/2025
#
# ...

# %%
df.tail()
# Out:
#      customer_id  gender       age       city signup_date order_id order_date  \
# 5995       C6849    Male     Adult     Multan  11/25/2024   O10849  8/22/2025
# 5996       C3787  Female     Adult  Islamabad   1/28/2025    O7787  8/22/2025
# 5997       C2841   Other  Teenager  Islamabad  10/19/2023    O6841  8/22/2025
# 5998       C1624    Male     Adult  Islamabad   6/17/2024    O5624  8/22/2025
# 5999       C2068  Female     Adult     Multan   3/15/2025    O6068  8/22/2025
#
#      restaurant_name dish_name   category  ...    price  payment_method  \
# 5995       Pizza Hut    Burger    Italian  ...   875.71            Cash
# 5996             KFC     Pizza    Italian  ...  1118.26            Cash
# 5997             KFC  Sandwich    Italian  ...  1005.83            Card
# 5998             KFC     Fries  Fast Food  ...  1226.10            Card
# 5999     Burger King     Fries  Fast Food  ...  1131.27            Card
#
# ...
