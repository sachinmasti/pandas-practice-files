# %% [markdown]
# practising pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/user/dsml-ghost/detasets/game_of_throne_1.csv')

# %%
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
df['attacker_2'].fillna(df['attacker_2'].mode()[0], inplace=True)

# %%
df.shape
# Out:
# (38, 25)

# %%
df.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                38 non-null     object
#  1   year                38 non-null     int64
#  2   battle_number       38 non-null     int64
#  3   attacker_king       36 non-null     object
#  4   defender_king       35 non-null     object
#  5   attacker_1          38 non-null     object
#  6   attacker_2          10 non-null     object
#  7   attacker_3          3 non-null      object
#  8   attacker_4          2 non-null      object
#  9   defender_1          37 non-null     object
#  10  defender_2          2 non-null      object
#  11  defender_3          0 non-null      float64
#  12  defender_4          0 non-null      float64
#  13  attacker_outcome    37 non-null     object
#  14  battle_type         37 non-null     object
# ...

# %%
df.isna().sum()
# Out:
# name                   0
# year                   0
# battle_number          0
# attacker_king          2
# defender_king          3
# attacker_1             0
# attacker_2            28
# attacker_3            35
# attacker_4            36
# defender_1             1
# defender_2            36
# defender_3            38
# defender_4            38
# attacker_outcome       1
# battle_type            1
# major_death            1
# major_capture          1
# attacker_size         14
# defender_size         19
# attacker_commander     1
# defender_commander    10
# summer                 1
# location               1
# region                 0
# note                  33
# dtype: int64

# %%
df['attacker_1']
# Out:
# 0                       Lannister
# 1                       Lannister
# 2                       Lannister
# 3                           Stark
# 4                           Stark
# 5                           Stark
# 6                       Lannister
# 7                         Greyjoy
# 8                         Greyjoy
# 9                         Greyjoy
# 10                          Stark
# 11                        Greyjoy
# 12                        Greyjoy
# 13                         Bolton
# 14                          Stark
# 15                      Baratheon
# 16                      Lannister
# 17                          Stark
# 18                          Stark
# 19                      Baratheon
# 20                          Darry
# 21                          Stark
# 22    Brotherhood without Banners
# 23                      Lannister
# 24                      Lannister
# 25                           Frey
# 26                           Frey
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
df[(df['year'] ==298) & (df['defender_king'] =='Robb Stark')]
# Out:
#                           name  year  battle_number             attacker_king  \
# 0   Battle of the Golden Tooth   298              1  Joffrey/Tommen Baratheon
# 1  Battle at the Mummer's Ford   298              2  Joffrey/Tommen Baratheon
# 2           Battle of Riverrun   298              3  Joffrey/Tommen Baratheon
# 6                Sack of Darry   298              7  Joffrey/Tommen Baratheon
#
#   defender_king attacker_1 attacker_2 attacker_3 attacker_4 defender_1  ...  \
# 0    Robb Stark  Lannister      Tully        NaN        NaN      Tully  ...
# 1    Robb Stark  Lannister      Tully        NaN        NaN  Baratheon  ...
# 2    Robb Stark  Lannister      Tully        NaN        NaN      Tully  ...
# 6    Robb Stark  Lannister      Tully        NaN        NaN      Darry  ...
#
#   major_death  major_capture  attacker_size defender_size  \
# 0         1.0            0.0        15000.0        4000.0
# 1         1.0            0.0            NaN         120.0
# ...

# %%
(df['year'] ==298).sum()
# Out:
# np.int64(7)

# %%
df.drop('attacker_3',axis=1,inplace=True)

# %%
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_4 defender_1 defender_2  ...  major_death  major_capture  \
# 0        NaN      Tully        NaN  ...          1.0            0.0
# ...

# %%
df.sort_values('name')
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_4 defender_1 defender_2  ...  major_death  major_capture  \
# 0        NaN      Tully        NaN  ...          1.0            0.0
# ...

# %%
df.reset_index(drop=True)
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_4 defender_1 defender_2  ...  major_death  major_capture  \
# 0        NaN      Tully        NaN  ...          1.0            0.0
# ...

# %%
df.groupby('defender_king')['year'].mean()
# Out:
# defender_king
# Balon/Euron Greyjoy         299.500000
# Joffrey/Tommen Baratheon    299.000000
# Mance Rayder                300.000000
# Renly Baratheon             299.000000
# Robb Stark                  298.857143
# Stannis Baratheon           300.000000
# Name: year, dtype: float64

# %%
df['new_col']= df.groupby('defender_king')['year'].transform('mean')

# %%
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister      Tully
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_4 defender_1 defender_2  ...  major_capture  attacker_size  \
# 0        NaN      Tully        NaN  ...            0.0        15000.0
# ...

# %%
df['name'].str.upper()
# Out:
# 0                            BATTLE OF THE GOLDEN TOOTH
# 1                           BATTLE AT THE MUMMER'S FORD
# 2                                    BATTLE OF RIVERRUN
# 3                              BATTLE OF THE GREEN FORK
# 4                         BATTLE OF THE WHISPERING WOOD
# 5                                   BATTLE OF THE CAMPS
# 6                                         SACK OF DARRY
# 7                                 BATTLE OF MOAT CAILIN
# 8                              BATTLE OF DEEPWOOD MOTTE
# 9                             BATTLE OF THE STONY SHORE
# 10                           BATTLE OF TORRHEN'S SQUARE
# 11                                 BATTLE OF WINTERFELL
# 12                             SACK OF TORRHEN'S SQUARE
# 13                                   SACK OF WINTERFELL
# 14                                    BATTLE OF OXCROSS
# 15                                 SIEGE OF STORM'S END
# 16                                  BATTLE OF THE FORDS
# ...

# %%
df['name'].str.title ()
# Out:
# 0                            Battle Of The Golden Tooth
# 1                           Battle At The Mummer'S Ford
# 2                                    Battle Of Riverrun
# 3                              Battle Of The Green Fork
# 4                         Battle Of The Whispering Wood
# 5                                   Battle Of The Camps
# 6                                         Sack Of Darry
# 7                                 Battle Of Moat Cailin
# 8                              Battle Of Deepwood Motte
# 9                             Battle Of The Stony Shore
# 10                           Battle Of Torrhen'S Square
# 11                                 Battle Of Winterfell
# 12                             Sack Of Torrhen'S Square
# 13                                   Sack Of Winterfell
# 14                                    Battle Of Oxcross
# 15                                 Siege Of Storm'S End
# 16                                  Battle Of The Fords
# ...

# %%
df['name'].str.contains('Battle of the blackwater',case = False).sum()
# Out:
# np.int64(1)

# %%
df.iloc[:10,[2,3,4]]
# Out:
#    battle_number             attacker_king             defender_king
# 0              1  Joffrey/Tommen Baratheon                Robb Stark
# 1              2  Joffrey/Tommen Baratheon                Robb Stark
# 2              3  Joffrey/Tommen Baratheon                Robb Stark
# 3              4                Robb Stark  Joffrey/Tommen Baratheon
# 4              5                Robb Stark  Joffrey/Tommen Baratheon
# 5              6                Robb Stark  Joffrey/Tommen Baratheon
# 6              7  Joffrey/Tommen Baratheon                Robb Stark
# 7              8       Balon/Euron Greyjoy                Robb Stark
# 8              9       Balon/Euron Greyjoy                Robb Stark
# 9             10       Balon/Euron Greyjoy                Robb Stark

# %%
df.loc[:10,['battle_number','attacker_king','defender_king']]
# Out:
#     battle_number             attacker_king             defender_king
# 0               1  Joffrey/Tommen Baratheon                Robb Stark
# 1               2  Joffrey/Tommen Baratheon                Robb Stark
# 2               3  Joffrey/Tommen Baratheon                Robb Stark
# 3               4                Robb Stark  Joffrey/Tommen Baratheon
# 4               5                Robb Stark  Joffrey/Tommen Baratheon
# 5               6                Robb Stark  Joffrey/Tommen Baratheon
# 6               7  Joffrey/Tommen Baratheon                Robb Stark
# 7               8       Balon/Euron Greyjoy                Robb Stark
# 8               9       Balon/Euron Greyjoy                Robb Stark
# 9              10       Balon/Euron Greyjoy                Robb Stark
# 10             11                Robb Stark       Balon/Euron Greyjoy

# %%
df.at[2,'battle_number']
# Out:
# np.int64(3)

# %%
df.iat[2,2]
# Out:
# np.int64(3)

# %%
df.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_4', 'defender_1', 'defender_2',
#        'defender_3', 'defender_4', 'attacker_outcome', 'battle_type',
#        'major_death', 'major_capture', 'attacker_size', 'defender_size',
#        'attacker_commander', 'defender_commander', 'summer', 'location',
#        'region', 'note', 'new_col'],
#       dtype='object')

# %%
df.query('year == 298 and attacker_king =="Robb Stark"')
# Out:
#                             name  year  battle_number attacker_king  \
# 3       Battle of the Green Fork   298              4    Robb Stark
# 4  Battle of the Whispering Wood   298              5    Robb Stark
# 5            Battle of the Camps   298              6    Robb Stark
#
#               defender_king attacker_1 attacker_2 attacker_4 defender_1  \
# 3  Joffrey/Tommen Baratheon      Stark      Tully        NaN  Lannister
# 4  Joffrey/Tommen Baratheon      Stark      Tully        NaN  Lannister
# 5  Joffrey/Tommen Baratheon      Stark      Tully        NaN  Lannister
#
#   defender_2  ...  major_capture  attacker_size defender_size  \
# 3        NaN  ...            1.0        18000.0       20000.0
# 4        NaN  ...            1.0         1875.0        6000.0
# 5        NaN  ...            0.0         6000.0       12625.0
#
#                                   attacker_commander  \
# 3  Roose Bolton, Wylis Manderly, Medger Cerwyn, H...
# ...
