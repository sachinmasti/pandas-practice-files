# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
        'Age': [17, 25, 19, 30, 15]}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age
# 0    Alice   17
# 1      Bob   25
# 2  Charlie   19
# 3    David   30
# 4      Eva   15

# %%
new_df = df.loc[df['Age'] > 18][['Name','Age']]

# %%
new_df
# Out:
#       Name  Age
# 1      Bob   25
# 2  Charlie   19
# 3    David   30

# %%
df[(df['Age']>=18) & (df['Name'].str.startswith('C'))] [['Name',"Age"]]
# Out:
#       Name  Age
# 2  Charlie   19

# %%
# df['Age_group'] = np.where(df['Age'] > 18 ,'Adult','Teen')

# %%
df
# Out:
#       Name  Age
# 0    Alice   17
# 1      Bob   25
# 2  Charlie   19
# 3    David   30
# 4      Eva   15

# %%
df['Age_group'] = np.select(
                    [df['Age'] < 18,(df['Age']>=18 ) & (df['Age'] < 25),df['Age']>= 25],
                    ['Teen','Young_Adult','Adult'],
                    default = 'Safe')

# %%
df
# Out:
#       Name  Age    Age_group
# 0    Alice   17         Teen
# 1      Bob   25        Adult
# 2  Charlie   19  Young_Adult
# 3    David   30        Adult
# 4      Eva   15         Teen

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
        'Age': [17, 25, 19, 30, 15],
        'House': ['Red', 'Blue', 'Red', 'Blue', 'Red']}
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#       Name  Age House
# 0    Alice   17   Red
# 1      Bob   25  Blue
# 2  Charlie   19   Red
# 3    David   30  Blue
# 4      Eva   15   Red

# %%
df.groupby('House') ['Age'].mean().reset_index(name = 'avg_age')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.groupby('House') ['Age'].mean().reset_index(name = 'avg_age')
#
# File ~/dsml-ghost/.venv/lib/python3.11/site-packages/pandas/core/frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# ...

# %%
df.groupby('House')['Age'].mean().reset_index(name='Average_Age')
# Out:
#   House  Average_Age
# 0  Blue         27.5
# 1   Red         17.0

# %%
df1[df1['Age']>=18].groupby('House')['Age'].mean().reset_index(name = 'Avg_Age_house')
# Out:
#   House  Avg_Age_house
# 0  Blue           27.5
# 1   Red           19.0

# %%
df1
# Out:
#       Name  Age House
# 0    Alice   17   Red
# 1      Bob   25  Blue
# 2  Charlie   19   Red
# 3    David   30  Blue
# 4      Eva   15   Red

# %%
# new_df1 = df[df['Age']>=18]

# %%
# new_df1
# Out:
#       Name  Age House
# 1      Bob   25  Blue
# 2  Charlie   19   Red
# 3    David   30  Blue

# %%
# new_df1.groupby('House')['Age'].mean().reset_index(name = 'Avg_house_age')
# Out:
#   House  Avg_house_age
# 0  Blue           27.5
# 1   Red           19.0

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
        'Age': [17, 25, 19, 30, 15],
        'House': ['Red', 'Blue', 'Red', 'Blue', 'Red'],
        'Score': [88, 92, 95, 85, 78]}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age House  Score
# 0    Alice   17   Red     88
# 1      Bob   25  Blue     92
# 2  Charlie   19   Red     95
# 3    David   30  Blue     85
# 4      Eva   15   Red     78

# %%
df['Age_gruou']  = df['Age'].apply(lambda y: 'Adult' if y >= 18 else 'young')

# %%
df
# Out:
#       Name  Age House  Score Age_gruou
# 0    Alice   17   Red     88     young
# 1      Bob   25  Blue     92     Adult
# 2  Charlie   19   Red     95     Adult
# 3    David   30  Blue     85     Adult
# 4      Eva   15   Red     78     young

# %%
avg_house_score = df.groupby('House')['Age'].mean()

# %%
df
# Out:
#       Name  Age House  Score Age_gruou
# 0    Alice   17   Red     88     young
# 1      Bob   25  Blue     92     Adult
# 2  Charlie   19   Red     95     Adult
# 3    David   30  Blue     85     Adult
# 4      Eva   15   Red     78     young
