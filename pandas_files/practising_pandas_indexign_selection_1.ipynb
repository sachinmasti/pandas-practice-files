# %% [markdown]
# practising pandas

# %%
import pandas as pd
# Out:
# Bad pipe message: %s [b' 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Sa']
# Bad pipe message: %s [b'ri/537.36\r\nAccept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/', b'ng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nAccept-Encoding: gzip, deflate, br, zstd\r\nA']
# Bad pipe message: %s [b'ept-Language: en-US,en;q=0.9,hi;q=0.8,mr;q=0.7\r\nPriority: u=0, i\r\nReferer: https://studio.firebase', b'oogle.com/\r\nSec-Ch-Ua: "Google Chrome";v="141', b' "Not?A_Brand";v="8", "Chromium";']
# Bad pipe message: %s [b'"141"\r\nSec-Ch-Ua-Arch: "x86"\r\nSec-Ch-Ua-Bitness: "64"\r\nSec-Ch-Ua-Form-Factors: "Desktop"\r\nSec-Ch-Ua-Full-Version: "14', b'0.7390.66"\r\nSec-Ch-Ua-Full-Version-List: "Google']
# ...

# %%
df = pd.read_csv('new_csv.csv')

# %%
df.shape
# Out:
# (6000, 21)

# %%
df.head()
# Out:
#    Unnamed: 0 customer_id  gender     age      city signup_date order_id  \
# 0           0       C5663    Male   Adult  Peshawar   1/14/2024    O9663
# 1           1       C2831    Male   Adult    Multan    7/7/2024    O6831
# 2           2       C2851   Other  Senior    Multan   6/20/2025    O6851
# 3           3       C1694  Female  Senior  Peshawar    9/5/2023    O5694
# 4           4       C4339   Other  Senior    Lahore  12/29/2023    O8339
#
#   order_date restaurant_name dish_name  ... quantity    price  payment_method  \
# 0  8/23/2023      McDonald's    Burger  ...        5  1478.27            Cash
# 1  8/23/2023             KFC    Burger  ...        3   956.04          Wallet
# 2  8/23/2023       Pizza Hut     Fries  ...        2   882.51            Cash
# 3  8/23/2023          Subway     Pizza  ...        4   231.30            Card
# 4  8/24/2023             KFC  Sandwich  ...        1  1156.69            Cash
#
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0     quantity        price  order_frequency  loyalty_points  \
# count  6000.000000  6000.000000  6000.000000      6000.000000     6000.000000
# mean   2999.500000     2.991667   800.524880        25.304667      250.173667
# std    1732.195139     1.414778   404.855029        14.358930      144.608478
# min       0.000000     1.000000   100.300000         1.000000        0.000000
# 25%    1499.750000     2.000000   441.997500        13.000000      125.000000
# 50%    2999.500000     3.000000   806.460000        25.000000      249.500000
# 75%    4499.250000     4.000000  1149.737500        37.000000      378.000000
# max    5999.000000     5.000000  1499.950000        50.000000      500.000000
#
#             rating
# count  6000.000000
# mean      2.996833
# std       1.406113
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       6000 non-null   int64
#  1   customer_id      6000 non-null   object
#  2   gender           6000 non-null   object
#  3   age              6000 non-null   object
#  4   city             6000 non-null   object
#  5   signup_date      6000 non-null   object
#  6   order_id         6000 non-null   object
#  7   order_date       6000 non-null   object
#  8   restaurant_name  6000 non-null   object
#  9   dish_name        6000 non-null   object
#  10  category         6000 non-null   object
#  11  quantity         6000 non-null   int64
#  12  price            6000 non-null   float64
#  13  payment_method   6000 non-null   object
#  14  order_frequency  6000 non-null   int64
#  15  last_order_date  6000 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'customer_id', 'gender', 'age', 'city', 'signup_date',
#        'order_id', 'order_date', 'restaurant_name', 'dish_name', 'category',
#        'quantity', 'price', 'payment_method', 'order_frequency',
#        'last_order_date', 'loyalty_points', 'churned', 'rating', 'rating_date',
#        'delivery_status'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.shape
# Out:
# (6000, 20)

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'signup_date', 'order_id',
#        'order_date', 'restaurant_name', 'dish_name', 'category', 'quantity',
#        'price', 'payment_method', 'order_frequency', 'last_order_date',
#        'loyalty_points', 'churned', 'rating', 'rating_date',
#        'delivery_status'],
#       dtype='object')

# %%
df[['customer_id','city','dish_name']]
# Out:
#      customer_id       city dish_name
# 0          C5663   Peshawar    Burger
# 1          C2831     Multan    Burger
# 2          C2851     Multan     Fries
# 3          C1694   Peshawar     Pizza
# 4          C4339     Lahore  Sandwich
# ...          ...        ...       ...
# 5995       C6849     Multan    Burger
# 5996       C3787  Islamabad     Pizza
# 5997       C2841  Islamabad  Sandwich
# 5998       C1624  Islamabad     Fries
# 5999       C2068     Multan     Fries
#
# [6000 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'signup_date', 'order_id',
#        'order_date', 'restaurant_name', 'dish_name', 'category', 'quantity',
#        'price', 'payment_method', 'order_frequency', 'last_order_date',
#        'loyalty_points', 'churned', 'rating', 'rating_date',
#        'delivery_status'],
#       dtype='object')

# %%
df.iloc[0:11,[3,8,11]]
# Out:
#         city dish_name    price
# 0   Peshawar    Burger  1478.27
# 1     Multan    Burger   956.04
# 2     Multan     Fries   882.51
# 3   Peshawar     Pizza   231.30
# 4     Lahore  Sandwich  1156.69
# 5    Karachi     Pizza  1213.62
# 6     Lahore     Pasta   672.91
# 7   Peshawar     Pizza   271.74
# 8    Karachi     Pizza   596.96
# 9    Karachi     Pizza  1443.25
# 10    Lahore  Sandwich   645.52

# %%
df.loc[0:11,['city','dish_name','price']]
# Out:
#         city dish_name    price
# 0   Peshawar    Burger  1478.27
# 1     Multan    Burger   956.04
# 2     Multan     Fries   882.51
# 3   Peshawar     Pizza   231.30
# 4     Lahore  Sandwich  1156.69
# 5    Karachi     Pizza  1213.62
# 6     Lahore     Pasta   672.91
# 7   Peshawar     Pizza   271.74
# 8    Karachi     Pizza   596.96
# 9    Karachi     Pizza  1443.25
# 10    Lahore  Sandwich   645.52
# 11    Multan    Burger   126.53

# %%
df.at[2,'city']
# Out:
# 'Multan'

# %%
df.iat[2,3]
# Out:
# 'Multan'

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'signup_date', 'order_id',
#        'order_date', 'restaurant_name', 'dish_name', 'category', 'quantity',
#        'price', 'payment_method', 'order_frequency', 'last_order_date',
#        'loyalty_points', 'churned', 'rating', 'rating_date',
#        'delivery_status'],
#       dtype='object')

# %%
df.head()
# Out:
#   customer_id  gender     age      city signup_date order_id order_date  \
# 0       C5663    Male   Adult  Peshawar   1/14/2024    O9663  8/23/2023
# 1       C2831    Male   Adult    Multan    7/7/2024    O6831  8/23/2023
# 2       C2851   Other  Senior    Multan   6/20/2025    O6851  8/23/2023
# 3       C1694  Female  Senior  Peshawar    9/5/2023    O5694  8/23/2023
# 4       C4339   Other  Senior    Lahore  12/29/2023    O8339  8/24/2023
#
#   restaurant_name dish_name category  quantity    price payment_method  \
# 0      McDonald's    Burger  Italian         5  1478.27           Cash
# 1             KFC    Burger  Italian         3   956.04         Wallet
# 2       Pizza Hut     Fries  Italian         2   882.51           Cash
# 3          Subway     Pizza  Dessert         4   231.30           Card
# 4             KFC  Sandwich  Dessert         1  1156.69           Cash
#
#    order_frequency last_order_date  loyalty_points   churned  rating  \
# ...

# %%
new_age = {'Adult':25,'Senior':60,'Teenage':15}
df['new_age'] = df['age'].map(new_age)

# %%
df.head()
# Out:
#   customer_id  gender     age      city signup_date order_id order_date  \
# 0       C5663    Male   Adult  Peshawar   1/14/2024    O9663  8/23/2023
# 1       C2831    Male   Adult    Multan    7/7/2024    O6831  8/23/2023
# 2       C2851   Other  Senior    Multan   6/20/2025    O6851  8/23/2023
# 3       C1694  Female  Senior  Peshawar    9/5/2023    O5694  8/23/2023
# 4       C4339   Other  Senior    Lahore  12/29/2023    O8339  8/24/2023
#
#   restaurant_name dish_name category  ...    price  payment_method  \
# 0      McDonald's    Burger  Italian  ...  1478.27            Cash
# 1             KFC    Burger  Italian  ...   956.04          Wallet
# 2       Pizza Hut     Fries  Italian  ...   882.51            Cash
# 3          Subway     Pizza  Dessert  ...   231.30            Card
# 4             KFC  Sandwich  Dessert  ...  1156.69            Cash
#
#   order_frequency  last_order_date loyalty_points   churned rating  \
# ...

# %%
import numpy as np

# %%
np.array(df['new_age'], dtype = 'int32')
# Out:
# /home/user/dsml-ghost/.venv/lib/python3.11/site-packages/pandas/core/series.py:1035: RuntimeWarning: invalid value encountered in cast
#   arr = np.array(values, dtype=dtype, copy=copy)
# array([         25,          25,          60, ..., -2147483648,
#                 25,          25], shape=(6000,), dtype=int32)

# %%
df.head()
# Out:
#   customer_id  gender     age      city signup_date order_id order_date  \
# 0       C5663    Male   Adult  Peshawar   1/14/2024    O9663  8/23/2023
# 1       C2831    Male   Adult    Multan    7/7/2024    O6831  8/23/2023
# 2       C2851   Other  Senior    Multan   6/20/2025    O6851  8/23/2023
# 3       C1694  Female  Senior  Peshawar    9/5/2023    O5694  8/23/2023
# 4       C4339   Other  Senior    Lahore  12/29/2023    O8339  8/24/2023
#
#   restaurant_name dish_name category  ...    price  payment_method  \
# 0      McDonald's    Burger  Italian  ...  1478.27            Cash
# 1             KFC    Burger  Italian  ...   956.04          Wallet
# 2       Pizza Hut     Fries  Italian  ...   882.51            Cash
# 3          Subway     Pizza  Dessert  ...   231.30            Card
# 4             KFC  Sandwich  Dessert  ...  1156.69            Cash
#
#   order_frequency  last_order_date loyalty_points   churned rating  \
# ...

# %%
df[(df['new_age'] > 18)  & (df['rating']> 3)]
# Out:
#      customer_id  gender     age       city signup_date order_id order_date  \
# 5          C6543   Other   Adult    Karachi   9/28/2023   O10543  8/24/2023
# 8          C5146   Other  Senior    Karachi  12/17/2024    O9146  8/24/2023
# 10         C5535    Male   Adult     Lahore   7/30/2025    O9535  8/24/2023
# 12         C4071    Male  Senior  Islamabad  12/27/2024    O8071  8/24/2023
# 13         C4231  Female  Senior     Multan   4/11/2025    O8231  8/24/2023
# ...          ...     ...     ...        ...         ...      ...        ...
# 5981       C1450  Female   Adult    Karachi   1/15/2025    O5450  8/21/2025
# 5984       C3042   Other   Adult     Multan   9/28/2024    O7042  8/21/2025
# 5985       C2877   Other   Adult   Peshawar   3/28/2025    O6877  8/21/2025
# 5986       C2893    Male   Adult     Multan   8/13/2024    O6893  8/21/2025
# 5995       C6849    Male   Adult     Multan  11/25/2024   O10849  8/22/2025
#
# ...

# %%
df.query('new_age > 20 and rating >3')
# Out:
#      customer_id  gender     age       city signup_date order_id order_date  \
# 5          C6543   Other   Adult    Karachi   9/28/2023   O10543  8/24/2023
# 8          C5146   Other  Senior    Karachi  12/17/2024    O9146  8/24/2023
# 10         C5535    Male   Adult     Lahore   7/30/2025    O9535  8/24/2023
# 12         C4071    Male  Senior  Islamabad  12/27/2024    O8071  8/24/2023
# 13         C4231  Female  Senior     Multan   4/11/2025    O8231  8/24/2023
# ...          ...     ...     ...        ...         ...      ...        ...
# 5981       C1450  Female   Adult    Karachi   1/15/2025    O5450  8/21/2025
# 5984       C3042   Other   Adult     Multan   9/28/2024    O7042  8/21/2025
# 5985       C2877   Other   Adult   Peshawar   3/28/2025    O6877  8/21/2025
# 5986       C2893    Male   Adult     Multan   8/13/2024    O6893  8/21/2025
# 5995       C6849    Male   Adult     Multan  11/25/2024   O10849  8/22/2025
#
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'signup_date', 'order_id',
#        'order_date', 'restaurant_name', 'dish_name', 'category', 'quantity',
#        'price', 'payment_method', 'order_frequency', 'last_order_date',
#        'loyalty_points', 'churned', 'rating', 'rating_date', 'delivery_status',
#        'new_age'],
#       dtype='object')

# %%
df['loyalty_points'] > 100
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 5995     True
# 5996     True
# 5997     True
# 5998    False
# 5999    False
# Name: loyalty_points, Length: 6000, dtype: bool

# %%
df[df['loyalty_points'] >100] ['city']
# Out:
# 0        Peshawar
# 4          Lahore
# 5         Karachi
# 6          Lahore
# 7        Peshawar
#           ...
# 5993     Peshawar
# 5994       Multan
# 5995       Multan
# 5996    Islamabad
# 5997    Islamabad
# Name: city, Length: 4814, dtype: object

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'signup_date', 'order_id',
#        'order_date', 'restaurant_name', 'dish_name', 'category', 'quantity',
#        'price', 'payment_method', 'order_frequency', 'last_order_date',
#        'loyalty_points', 'churned', 'rating', 'rating_date', 'delivery_status',
#        'new_age'],
#       dtype='object')

# %%
df[(df['loyalty_points']>100) & (df['new_age']>20)]
# Out:
#      customer_id  gender     age       city signup_date order_id order_date  \
# 0          C5663    Male   Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 4          C4339   Other  Senior     Lahore  12/29/2023    O8339  8/24/2023
# 5          C6543   Other   Adult    Karachi   9/28/2023   O10543  8/24/2023
# 6          C6423    Male   Adult     Lahore    4/8/2025   O10423  8/24/2023
# 7          C4621    Male   Adult   Peshawar    2/5/2024    O8621  8/24/2023
# ...          ...     ...     ...        ...         ...      ...        ...
# 5991       C5793   Other  Senior     Multan   10/1/2023    O9793  8/21/2025
# 5993       C5777  Female  Senior   Peshawar   2/11/2024    O9777  8/22/2025
# 5994       C5590  Female   Adult     Multan   8/11/2024    O9590  8/22/2025
# 5995       C6849    Male   Adult     Multan  11/25/2024   O10849  8/22/2025
# 5996       C3787  Female   Adult  Islamabad   1/28/2025    O7787  8/22/2025
#
# ...

# %%
df.query('loyalty_points > 100 and new_age > 20')
# Out:
#      customer_id  gender     age       city signup_date order_id order_date  \
# 0          C5663    Male   Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 4          C4339   Other  Senior     Lahore  12/29/2023    O8339  8/24/2023
# 5          C6543   Other   Adult    Karachi   9/28/2023   O10543  8/24/2023
# 6          C6423    Male   Adult     Lahore    4/8/2025   O10423  8/24/2023
# 7          C4621    Male   Adult   Peshawar    2/5/2024    O8621  8/24/2023
# ...          ...     ...     ...        ...         ...      ...        ...
# 5991       C5793   Other  Senior     Multan   10/1/2023    O9793  8/21/2025
# 5993       C5777  Female  Senior   Peshawar   2/11/2024    O9777  8/22/2025
# 5994       C5590  Female   Adult     Multan   8/11/2024    O9590  8/22/2025
# 5995       C6849    Male   Adult     Multan  11/25/2024   O10849  8/22/2025
# 5996       C3787  Female   Adult  Islamabad   1/28/2025    O7787  8/22/2025
#
# ...

# %%
df[(df['loyalty_points']>100) & (df['new_age']>20)]
# Out:
#      customer_id  gender     age       city signup_date order_id order_date  \
# 0          C5663    Male   Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 4          C4339   Other  Senior     Lahore  12/29/2023    O8339  8/24/2023
# 5          C6543   Other   Adult    Karachi   9/28/2023   O10543  8/24/2023
# 6          C6423    Male   Adult     Lahore    4/8/2025   O10423  8/24/2023
# 7          C4621    Male   Adult   Peshawar    2/5/2024    O8621  8/24/2023
# ...          ...     ...     ...        ...         ...      ...        ...
# 5991       C5793   Other  Senior     Multan   10/1/2023    O9793  8/21/2025
# 5993       C5777  Female  Senior   Peshawar   2/11/2024    O9777  8/22/2025
# 5994       C5590  Female   Adult     Multan   8/11/2024    O9590  8/22/2025
# 5995       C6849    Male   Adult     Multan  11/25/2024   O10849  8/22/2025
# 5996       C3787  Female   Adult  Islamabad   1/28/2025    O7787  8/22/2025
#
# ...

# %%
df.query('loyalty_points > 100 and new_age == 25')
# Out:
#      customer_id  gender    age       city signup_date order_id order_date  \
# 0          C5663    Male  Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 5          C6543   Other  Adult    Karachi   9/28/2023   O10543  8/24/2023
# 6          C6423    Male  Adult     Lahore    4/8/2025   O10423  8/24/2023
# 7          C4621    Male  Adult   Peshawar    2/5/2024    O8621  8/24/2023
# 9          C3579    Male  Adult    Karachi  10/13/2023    O7579  8/24/2023
# ...          ...     ...    ...        ...         ...      ...        ...
# 5985       C2877   Other  Adult   Peshawar   3/28/2025    O6877  8/21/2025
# 5986       C2893    Male  Adult     Multan   8/13/2024    O6893  8/21/2025
# 5994       C5590  Female  Adult     Multan   8/11/2024    O9590  8/22/2025
# 5995       C6849    Male  Adult     Multan  11/25/2024   O10849  8/22/2025
# 5996       C3787  Female  Adult  Islamabad   1/28/2025    O7787  8/22/2025
#
# ...

# %%
df[(df['loyalty_points']>100) & (df['new_age'] == 25)]
# Out:
#      customer_id  gender    age       city signup_date order_id order_date  \
# 0          C5663    Male  Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 5          C6543   Other  Adult    Karachi   9/28/2023   O10543  8/24/2023
# 6          C6423    Male  Adult     Lahore    4/8/2025   O10423  8/24/2023
# 7          C4621    Male  Adult   Peshawar    2/5/2024    O8621  8/24/2023
# 9          C3579    Male  Adult    Karachi  10/13/2023    O7579  8/24/2023
# ...          ...     ...    ...        ...         ...      ...        ...
# 5985       C2877   Other  Adult   Peshawar   3/28/2025    O6877  8/21/2025
# 5986       C2893    Male  Adult     Multan   8/13/2024    O6893  8/21/2025
# 5994       C5590  Female  Adult     Multan   8/11/2024    O9590  8/22/2025
# 5995       C6849    Male  Adult     Multan  11/25/2024   O10849  8/22/2025
# 5996       C3787  Female  Adult  Islamabad   1/28/2025    O7787  8/22/2025
#
# ...

# %%
df.loc[1:11,['dish_name']]
# Out:
#    dish_name
# 1     Burger
# 2      Fries
# 3      Pizza
# 4   Sandwich
# 5      Pizza
# 6      Pasta
# 7      Pizza
# 8      Pizza
# 9      Pizza
# 10  Sandwich
# 11    Burger

# %%
df.iloc[1:11,[8,3]]
# Out:
#    dish_name      city
# 1     Burger    Multan
# 2      Fries    Multan
# 3      Pizza  Peshawar
# 4   Sandwich    Lahore
# 5      Pizza   Karachi
# 6      Pasta    Lahore
# 7      Pizza  Peshawar
# 8      Pizza   Karachi
# 9      Pizza   Karachi
# 10  Sandwich    Lahore

# %%
df[(df['dish_name'] == 'Pizza') & (df['city'] == 'Karachi')]
# Out:
#      customer_id  gender       age     city signup_date order_id order_date  \
# 5          C6543   Other     Adult  Karachi   9/28/2023   O10543  8/24/2023
# 8          C5146   Other    Senior  Karachi  12/17/2024    O9146  8/24/2023
# 9          C3579    Male     Adult  Karachi  10/13/2023    O7579  8/24/2023
# 47         C2454   Other  Teenager  Karachi   12/4/2023    O6454  8/27/2023
# 63         C2727   Other    Senior  Karachi  11/27/2024    O6727  8/30/2023
# ...          ...     ...       ...      ...         ...      ...        ...
# 5889       C4015    Male  Teenager  Karachi    2/7/2025    O8015   8/9/2025
# 5911       C5593    Male     Adult  Karachi  10/10/2023    O9593  8/12/2025
# 5936       C4992    Male  Teenager  Karachi   5/30/2025    O8992  8/14/2025
# 5941       C4614  Female  Teenager  Karachi  12/27/2024    O8614  8/15/2025
# 5981       C1450  Female     Adult  Karachi   1/15/2025    O5450  8/21/2025
#
# ...

# %%
df['new_age'].isna().sum()
# Out:
# np.int64(2062)

# %%
df['age'].isna().sum()
# Out:
# np.int64(0)

# %%
df[df['loyalty_points']>100] ['city']
# Out:
# 0        Peshawar
# 4          Lahore
# 5         Karachi
# 6          Lahore
# 7        Peshawar
#           ...
# 5993     Peshawar
# 5994       Multan
# 5995       Multan
# 5996    Islamabad
# 5997    Islamabad
# Name: city, Length: 4814, dtype: object

# %%
df.query('loyalty_points > 100')['city']
# Out:
# 0        Peshawar
# 4          Lahore
# 5         Karachi
# 6          Lahore
# 7        Peshawar
#           ...
# 5993     Peshawar
# 5994       Multan
# 5995       Multan
# 5996    Islamabad
# 5997    Islamabad
# Name: city, Length: 4814, dtype: object

# %%
df.head()
# Out:
#   customer_id  gender     age      city signup_date order_id order_date  \
# 0       C5663    Male   Adult  Peshawar   1/14/2024    O9663  8/23/2023
# 1       C2831    Male   Adult    Multan    7/7/2024    O6831  8/23/2023
# 2       C2851   Other  Senior    Multan   6/20/2025    O6851  8/23/2023
# 3       C1694  Female  Senior  Peshawar    9/5/2023    O5694  8/23/2023
# 4       C4339   Other  Senior    Lahore  12/29/2023    O8339  8/24/2023
#
#   restaurant_name dish_name category  ...    price  payment_method  \
# 0      McDonald's    Burger  Italian  ...  1478.27            Cash
# 1             KFC    Burger  Italian  ...   956.04          Wallet
# 2       Pizza Hut     Fries  Italian  ...   882.51            Cash
# 3          Subway     Pizza  Dessert  ...   231.30            Card
# 4             KFC  Sandwich  Dessert  ...  1156.69            Cash
#
#   order_frequency  last_order_date loyalty_points   churned rating  \
# ...

# %%
(df['payment_method'] == 'Cash').sum()
# Out:
# np.int64(2039)

# %%
(df['restaurant_name'] == 'KFC').sum()
# Out:
# np.int64(1224)

# %%
(df['restaurant_name'] == 'Pizza Hut').sum()
# Out:
# np.int64(1224)

# %%
df.head()
# Out:
#   customer_id  gender     age      city signup_date order_id order_date  \
# 0       C5663    Male   Adult  Peshawar   1/14/2024    O9663  8/23/2023
# 1       C2831    Male   Adult    Multan    7/7/2024    O6831  8/23/2023
# 2       C2851   Other  Senior    Multan   6/20/2025    O6851  8/23/2023
# 3       C1694  Female  Senior  Peshawar    9/5/2023    O5694  8/23/2023
# 4       C4339   Other  Senior    Lahore  12/29/2023    O8339  8/24/2023
#
#   restaurant_name dish_name category  ...    price  payment_method  \
# 0      McDonald's    Burger  Italian  ...  1478.27            Cash
# 1             KFC    Burger  Italian  ...   956.04          Wallet
# 2       Pizza Hut     Fries  Italian  ...   882.51            Cash
# 3          Subway     Pizza  Dessert  ...   231.30            Card
# 4             KFC  Sandwich  Dessert  ...  1156.69            Cash
#
#   order_frequency  last_order_date loyalty_points   churned rating  \
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'signup_date', 'order_id',
#        'order_date', 'restaurant_name', 'dish_name', 'category', 'quantity',
#        'price', 'payment_method', 'order_frequency', 'last_order_date',
#        'loyalty_points', 'churned', 'rating', 'rating_date', 'delivery_status',
#        'new_age'],
#       dtype='object')

# %%
df[(df['city'] == 'Multan') & (df['payment_method'] == 'Cash')]
# Out:
#      customer_id  gender       age    city signup_date order_id order_date  \
# 2          C2851   Other    Senior  Multan   6/20/2025    O6851  8/23/2023
# 32         C6340    Male    Senior  Multan    7/7/2025   O10340  8/26/2023
# 46         C3247  Female    Senior  Multan  11/27/2023    O7247  8/27/2023
# 81         C3775   Other     Adult  Multan  12/29/2024    O7775   9/1/2023
# 95         C5122   Other    Senior  Multan   3/30/2025    O9122   9/3/2023
# ...          ...     ...       ...     ...         ...      ...        ...
# 5971       C2798  Female  Teenager  Multan   8/25/2024    O6798  8/19/2025
# 5980       C4726  Female  Teenager  Multan   5/29/2024    O8726  8/20/2025
# 5986       C2893    Male     Adult  Multan   8/13/2024    O6893  8/21/2025
# 5991       C5793   Other    Senior  Multan   10/1/2023    O9793  8/21/2025
# 5995       C6849    Male     Adult  Multan  11/25/2024   O10849  8/22/2025
#
# ...

# %%
(df['city'] == 'Multan').sum()
# Out:
# np.int64(1256)

# %%
df
# Out:
#      customer_id  gender       age       city signup_date order_id order_date  \
# 0          C5663    Male     Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 1          C2831    Male     Adult     Multan    7/7/2024    O6831  8/23/2023
# 2          C2851   Other    Senior     Multan   6/20/2025    O6851  8/23/2023
# 3          C1694  Female    Senior   Peshawar    9/5/2023    O5694  8/23/2023
# 4          C4339   Other    Senior     Lahore  12/29/2023    O8339  8/24/2023
# ...          ...     ...       ...        ...         ...      ...        ...
# 5995       C6849    Male     Adult     Multan  11/25/2024   O10849  8/22/2025
# 5996       C3787  Female     Adult  Islamabad   1/28/2025    O7787  8/22/2025
# 5997       C2841   Other  Teenager  Islamabad  10/19/2023    O6841  8/22/2025
# 5998       C1624    Male     Adult  Islamabad   6/17/2024    O5624  8/22/2025
# 5999       C2068  Female     Adult     Multan   3/15/2025    O6068  8/22/2025
#
# ...
