# %% [markdown]
# data transformation using pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('new_csv.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 customer_id  gender     age      city signup_date order_id  \
# 0           0       C5663    Male   Adult  Peshawar   1/14/2024    O9663
# 1           1       C2831    Male   Adult    Multan    7/7/2024    O6831
# 2           2       C2851   Other  Senior    Multan   6/20/2025    O6851
# 3           3       C1694  Female  Senior  Peshawar    9/5/2023    O5694
# 4           4       C4339   Other  Senior    Lahore  12/29/2023    O8339
#
#   order_date restaurant_name dish_name  ... quantity    price  payment_method  \
# 0  8/23/2023      McDonald's    Burger  ...        5  1478.27            Cash
# 1  8/23/2023             KFC    Burger  ...        3   956.04          Wallet
# 2  8/23/2023       Pizza Hut     Fries  ...        2   882.51            Cash
# 3  8/23/2023          Subway     Pizza  ...        4   231.30            Card
# 4  8/24/2023             KFC  Sandwich  ...        1  1156.69            Cash
#
#   order_frequency  last_order_date loyalty_points   churned rating  \
# 0              38        7/19/2025            238    Active      3
# 1              24       11/25/2024             81    Active      2
# 2              42        5/10/2025             82  Inactive      3
# 3              27        7/24/2025             45  Inactive      2
# 4              35       12/21/2024            418  Inactive      3
#
#    rating_date delivery_status
# 0   10/14/2024       Cancelled
# 1    8/21/2025         Delayed
# 2    9/19/2024         Delayed
# 3    6/29/2025         Delayed
# 4     3/6/2025       Cancelled
#
# [5 rows x 21 columns]

# %%
df.sort_values('city' , ascending=False)
# Out:
#       Unnamed: 0 customer_id  gender       age       city signup_date  \
# 0              0       C5663    Male     Adult   Peshawar   1/14/2024
# 3696        3696       C5794    Male  Teenager   Peshawar    8/6/2025
# 1204        1204       C6859   Other    Senior   Peshawar  10/23/2023
# 3664        3664       C1000  Female  Teenager   Peshawar   6/14/2024
# 3666        3666       C3092    Male     Adult   Peshawar   6/16/2025
# ...          ...         ...     ...       ...        ...         ...
# 787          787       C1932   Other    Senior  Islamabad  10/27/2023
# 3063        3063       C3528  Female     Adult  Islamabad   5/20/2025
# 1535        1535       C1250    Male    Senior  Islamabad  10/20/2023
# 5129        5129       C4671    Male    Senior  Islamabad  12/28/2024
# 941          941       C4593    Male  Teenager  Islamabad  12/20/2023
#
#      order_id  order_date restaurant_name dish_name  ... quantity    price  \
# 0       O9663   8/23/2023      McDonald's    Burger  ...        5  1478.27
# 3696    O9794  11/12/2024             KFC     Pizza  ...        3   760.32
# 1204   O10859   1/13/2024             KFC     Pasta  ...        3   278.25
# 3664    O5000   11/8/2024       Pizza Hut     Pasta  ...        1  1210.10
# 3666    O7092   11/8/2024     Burger King     Pasta  ...        5   915.20
# ...       ...         ...             ...       ...  ...      ...      ...
# 787     O5932  11/24/2023       Pizza Hut    Burger  ...        5   224.54
# 3063    O7528   8/29/2024             KFC     Fries  ...        2   162.61
# 1535    O5250   2/24/2024          Subway    Burger  ...        1   624.23
# 5129    O8671    5/4/2025      McDonald's  Sandwich  ...        2  1072.35
# 941     O8593  12/12/2023             KFC     Pasta  ...        2   512.23
#
#       payment_method order_frequency  last_order_date loyalty_points  \
# 0               Cash              38        7/19/2025            238
# 3696          Wallet              18         8/2/2025            334
# 1204          Wallet              44         2/8/2025            315
# 3664          Wallet              26        4/17/2025             89
# 3666          Wallet              39       12/25/2024            217
# ...              ...             ...              ...            ...
# 787             Card               9         8/2/2025            390
# 3063            Cash              10       12/28/2024            366
# 1535          Wallet              19        5/11/2025            214
# 5129          Wallet              26         7/9/2025            107
# 941           Wallet               6        12/2/2024            498
#
#        churned rating  rating_date delivery_status
# 0       Active      3   10/14/2024       Cancelled
# 3696    Active      1    9/13/2024       Delivered
# 1204  Inactive      4    11/1/2024       Cancelled
# 3664  Inactive      5    9/30/2024       Cancelled
# 3666    Active      2    9/28/2024       Delivered
# ...        ...    ...          ...             ...
# 787   Inactive      2    4/25/2025         Delayed
# 3063  Inactive      1   11/30/2024       Cancelled
# 1535    Active      4    5/25/2025       Delivered
# 5129  Inactive      2   11/10/2024       Cancelled
# 941   Inactive      2   11/18/2024       Delivered
#
# [6000 rows x 21 columns]

# %%
df2 = df.sort_values(['city','payment_method']).copy()

# %%
df2.reset_index(drop=True,inplace=True)

# %%
df2
# Out:
#       Unnamed: 0 customer_id  gender       age       city signup_date  \
# 0             12       C4071    Male    Senior  Islamabad  12/27/2024
# 1             29       C5795  Female    Senior  Islamabad   11/7/2023
# 2             30       C5513    Male  Teenager  Islamabad   7/20/2025
# 3             31       C6362  Female    Senior  Islamabad  11/22/2023
# 4             41       C5009    Male  Teenager  Islamabad   3/25/2024
# ...          ...         ...     ...       ...        ...         ...
# 5995        5964       C6477    Male     Adult   Peshawar  10/18/2023
# 5996        5965       C6560    Male    Senior   Peshawar   7/12/2024
# 5997        5968       C2655   Other    Senior   Peshawar   1/15/2025
# 5998        5970       C3043  Female     Adult   Peshawar    3/3/2024
# 5999        5993       C5777  Female    Senior   Peshawar   2/11/2024
#
#      order_id order_date restaurant_name dish_name  ... quantity    price  \
# 0       O8071  8/24/2023          Subway     Pizza  ...        1   465.75
# 1       O9795  8/26/2023             KFC     Pizza  ...        5  1267.20
# 2       O9513  8/26/2023             KFC     Pizza  ...        3  1044.89
# 3      O10362  8/26/2023     Burger King     Pizza  ...        4   343.52
# 4       O9009  8/27/2023       Pizza Hut     Pizza  ...        3   795.30
# ...       ...        ...             ...       ...  ...      ...      ...
# 5995   O10477  8/18/2025     Burger King     Pasta  ...        2   185.72
# 5996   O10560  8/18/2025       Pizza Hut    Burger  ...        3   683.25
# 5997    O6655  8/18/2025          Subway     Pizza  ...        3  1042.43
# 5998    O7043  8/19/2025       Pizza Hut     Pasta  ...        3  1402.34
# 5999    O9777  8/22/2025       Pizza Hut     Pasta  ...        1  1103.73
#
#       payment_method order_frequency  last_order_date loyalty_points  \
# 0               Card              29       12/26/2024            394
# 1               Card              32       11/10/2024             72
# 2               Card              31        9/15/2024            496
# 3               Card              34        9/29/2024            164
# 4               Card              15         6/2/2025            179
# ...              ...             ...              ...            ...
# 5995          Wallet              50       10/30/2024            440
# 5996          Wallet              24       11/18/2024            306
# 5997          Wallet               9         6/7/2025            463
# 5998          Wallet               8        1/29/2025            355
# 5999          Wallet              43        8/21/2025            211
#
#        churned rating  rating_date delivery_status
# 0       Active      4    4/16/2025       Cancelled
# 1       Active      5   10/21/2024         Delayed
# 2     Inactive      2   12/27/2024         Delayed
# 3       Active      3    1/25/2025       Delivered
# 4     Inactive      4    1/13/2025         Delayed
# ...        ...    ...          ...             ...
# 5995    Active      3    2/21/2025       Cancelled
# 5996  Inactive      2    6/15/2025       Delivered
# 5997    Active      4    1/31/2025       Cancelled
# 5998  Inactive      1     6/5/2025         Delayed
# 5999  Inactive      1     9/4/2024       Delivered
#
# [6000 rows x 21 columns]

# %%
df2['Rank'] = df['customer_id'].rank(ascending = True,method='dense')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#            city customer_id  gender       age       city signup_date order_id  \
# 0      Peshawar       C5663    Male     Adult   Peshawar   1/14/2024    O9663
# 1        Multan       C2831    Male     Adult     Multan    7/7/2024    O6831
# 2        Multan       C2851   Other    Senior     Multan   6/20/2025    O6851
# 3      Peshawar       C1694  Female    Senior   Peshawar    9/5/2023    O5694
# 4        Lahore       C4339   Other    Senior     Lahore  12/29/2023    O8339
# ...         ...         ...     ...       ...        ...         ...      ...
# 5995     Multan       C6849    Male     Adult     Multan  11/25/2024   O10849
# 5996  Islamabad       C3787  Female     Adult  Islamabad   1/28/2025    O7787
# 5997  Islamabad       C2841   Other  Teenager  Islamabad  10/19/2023    O6841
# 5998  Islamabad       C1624    Male     Adult  Islamabad   6/17/2024    O5624
# 5999     Multan       C2068  Female     Adult     Multan   3/15/2025    O6068
#
#      order_date restaurant_name dish_name  ... quantity    price  \
# 0     8/23/2023      McDonald's    Burger  ...        5  1478.27
# 1     8/23/2023             KFC    Burger  ...        3   956.04
# 2     8/23/2023       Pizza Hut     Fries  ...        2   882.51
# 3     8/23/2023          Subway     Pizza  ...        4   231.30
# 4     8/24/2023             KFC  Sandwich  ...        1  1156.69
# ...         ...             ...       ...  ...      ...      ...
# 5995  8/22/2025       Pizza Hut    Burger  ...        4   875.71
# 5996  8/22/2025             KFC     Pizza  ...        5  1118.26
# 5997  8/22/2025             KFC  Sandwich  ...        4  1005.83
# 5998  8/22/2025             KFC     Fries  ...        4  1226.10
# 5999  8/22/2025     Burger King     Fries  ...        3  1131.27
#
#       payment_method order_frequency  last_order_date loyalty_points  \
# 0               Cash              38        7/19/2025            238
# 1             Wallet              24       11/25/2024             81
# 2               Cash              42        5/10/2025             82
# 3               Card              27        7/24/2025             45
# 4               Cash              35       12/21/2024            418
# ...              ...             ...              ...            ...
# 5995            Cash              28       11/29/2024            166
# 5996            Cash              12         6/8/2025            193
# 5997            Card              31       12/30/2024            278
# 5998            Card              37       12/27/2024             55
# 5999            Card               2        6/13/2025             41
#
#        churned rating  rating_date delivery_status
# 0       Active      3   10/14/2024       Cancelled
# 1       Active      2    8/21/2025         Delayed
# 2     Inactive      3    9/19/2024         Delayed
# 3     Inactive      2    6/29/2025         Delayed
# 4     Inactive      3     3/6/2025       Cancelled
# ...        ...    ...          ...             ...
# 5995    Active      5   12/30/2024       Cancelled
# 5996  Inactive      3     2/9/2025         Delayed
# 5997    Active      4    3/23/2025       Cancelled
# 5998  Inactive      2    3/15/2025       Delivered
# 5999  Inactive      1    7/15/2025         Delayed
#
# [6000 rows x 21 columns]

# %%
df2
# Out:
#       Unnamed: 0 customer_id  gender       age       city signup_date  \
# 0             12       C4071    Male    Senior  Islamabad  12/27/2024
# 1             29       C5795  Female    Senior  Islamabad   11/7/2023
# 2             30       C5513    Male  Teenager  Islamabad   7/20/2025
# 3             31       C6362  Female    Senior  Islamabad  11/22/2023
# 4             41       C5009    Male  Teenager  Islamabad   3/25/2024
# ...          ...         ...     ...       ...        ...         ...
# 5995        5964       C6477    Male     Adult   Peshawar  10/18/2023
# 5996        5965       C6560    Male    Senior   Peshawar   7/12/2024
# 5997        5968       C2655   Other    Senior   Peshawar   1/15/2025
# 5998        5970       C3043  Female     Adult   Peshawar    3/3/2024
# 5999        5993       C5777  Female    Senior   Peshawar   2/11/2024
#
#      order_id order_date restaurant_name dish_name  ...    price  \
# 0       O8071  8/24/2023          Subway     Pizza  ...   465.75
# 1       O9795  8/26/2023             KFC     Pizza  ...  1267.20
# 2       O9513  8/26/2023             KFC     Pizza  ...  1044.89
# 3      O10362  8/26/2023     Burger King     Pizza  ...   343.52
# 4       O9009  8/27/2023       Pizza Hut     Pizza  ...   795.30
# ...       ...        ...             ...       ...  ...      ...
# 5995   O10477  8/18/2025     Burger King     Pasta  ...   185.72
# 5996   O10560  8/18/2025       Pizza Hut    Burger  ...   683.25
# 5997    O6655  8/18/2025          Subway     Pizza  ...  1042.43
# 5998    O7043  8/19/2025       Pizza Hut     Pasta  ...  1402.34
# 5999    O9777  8/22/2025       Pizza Hut     Pasta  ...  1103.73
#
#       payment_method  order_frequency last_order_date  loyalty_points  \
# 0               Card               29      12/26/2024             394
# 1               Card               32      11/10/2024              72
# 2               Card               31       9/15/2024             496
# 3               Card               34       9/29/2024             164
# 4               Card               15        6/2/2025             179
# ...              ...              ...             ...             ...
# 5995          Wallet               50      10/30/2024             440
# 5996          Wallet               24      11/18/2024             306
# 5997          Wallet                9        6/7/2025             463
# 5998          Wallet                8       1/29/2025             355
# 5999          Wallet               43       8/21/2025             211
#
#        churned  rating rating_date  delivery_status    Rank
# 0       Active       4   4/16/2025        Cancelled  4664.0
# 1       Active       5  10/21/2024          Delayed  1832.0
# 2     Inactive       2  12/27/2024          Delayed  1852.0
# 3       Active       3   1/25/2025        Delivered   695.0
# 4     Inactive       4   1/13/2025          Delayed  3340.0
# ...        ...     ...         ...              ...     ...
# 5995    Active       3   2/21/2025        Cancelled  5850.0
# 5996  Inactive       2   6/15/2025        Delivered  2788.0
# 5997    Active       4   1/31/2025        Cancelled  1842.0
# 5998  Inactive       1    6/5/2025          Delayed   625.0
# 5999  Inactive       1    9/4/2024        Delivered  1069.0
#
# [6000 rows x 22 columns]

# %%
cols = ['city'] + [col for col in df.columns if col != ['city']]

# %%
df = df[cols]

# %%
df
# Out:
#            city  Unnamed: 0 customer_id  gender       age       city  \
# 0      Peshawar           0       C5663    Male     Adult   Peshawar
# 1        Multan           1       C2831    Male     Adult     Multan
# 2        Multan           2       C2851   Other    Senior     Multan
# 3      Peshawar           3       C1694  Female    Senior   Peshawar
# 4        Lahore           4       C4339   Other    Senior     Lahore
# ...         ...         ...         ...     ...       ...        ...
# 5995     Multan        5995       C6849    Male     Adult     Multan
# 5996  Islamabad        5996       C3787  Female     Adult  Islamabad
# 5997  Islamabad        5997       C2841   Other  Teenager  Islamabad
# 5998  Islamabad        5998       C1624    Male     Adult  Islamabad
# 5999     Multan        5999       C2068  Female     Adult     Multan
#
#      signup_date order_id order_date restaurant_name  ... quantity    price  \
# 0      1/14/2024    O9663  8/23/2023      McDonald's  ...        5  1478.27
# 1       7/7/2024    O6831  8/23/2023             KFC  ...        3   956.04
# 2      6/20/2025    O6851  8/23/2023       Pizza Hut  ...        2   882.51
# 3       9/5/2023    O5694  8/23/2023          Subway  ...        4   231.30
# 4     12/29/2023    O8339  8/24/2023             KFC  ...        1  1156.69
# ...          ...      ...        ...             ...  ...      ...      ...
# 5995  11/25/2024   O10849  8/22/2025       Pizza Hut  ...        4   875.71
# 5996   1/28/2025    O7787  8/22/2025             KFC  ...        5  1118.26
# 5997  10/19/2023    O6841  8/22/2025             KFC  ...        4  1005.83
# 5998   6/17/2024    O5624  8/22/2025             KFC  ...        4  1226.10
# 5999   3/15/2025    O6068  8/22/2025     Burger King  ...        3  1131.27
#
#       payment_method  order_frequency last_order_date  loyalty_points  \
# 0               Cash               38       7/19/2025             238
# 1             Wallet               24      11/25/2024              81
# 2               Cash               42       5/10/2025              82
# 3               Card               27       7/24/2025              45
# 4               Cash               35      12/21/2024             418
# ...              ...              ...             ...             ...
# 5995            Cash               28      11/29/2024             166
# 5996            Cash               12        6/8/2025             193
# 5997            Card               31      12/30/2024             278
# 5998            Card               37      12/27/2024              55
# 5999            Card                2       6/13/2025              41
#
#        churned  rating rating_date  delivery_status
# 0       Active       3  10/14/2024        Cancelled
# 1       Active       2   8/21/2025          Delayed
# 2     Inactive       3   9/19/2024          Delayed
# 3     Inactive       2   6/29/2025          Delayed
# 4     Inactive       3    3/6/2025        Cancelled
# ...        ...     ...         ...              ...
# 5995    Active       5  12/30/2024        Cancelled
# 5996  Inactive       3    2/9/2025          Delayed
# 5997    Active       4   3/23/2025        Cancelled
# 5998  Inactive       2   3/15/2025        Delivered
# 5999  Inactive       1   7/15/2025          Delayed
#
# [6000 rows x 22 columns]

# %%
sm = pd.read_csv('missing_values_data.csv')

# %%
sm.head()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019

# %%
sm.sort_values('Name')
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
sm.reset_index()
# Out:
#    index     Name   Age         City Gender              Email   Join Date
# 0      0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1      1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3      3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4      4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6      6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7      7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8      8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
sm.reset_index(drop=True)
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
sm
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
co = ['City']+[l for l in sm.columns if l !=['City']]
# sm = sm[co]

# %%
sm = sm[co]

# %%
sm
# Out:
#           City     Name   Age         City Gender              Email  \
# 0     New York    Alice  25.0     New York      F  alice@example.com
# 1        Delhi  Charlie   NaN        Delhi      M    charlie@example
# 2  Los Angeles      Bob  30.0  Los Angeles      M    bob@example.com
# 3        Delhi  Charlie   NaN        Delhi      M    charlie@example
# 4       Mumbai    David  22.0       Mumbai      M  david@example.com
# 5        Delhi      NaN  28.0        Delhi      F     eve@domain.com
# 6     New York    Alice  25.0     New York      F  alice@example.com
# 7     New York    Alice  25.0     New York      F  alice@example.com
# 8        Delhi  Charlie   NaN        Delhi      M    charlie@example
#
#     Join Date
# 0  01-05-2021
# 1  20-07-2021
# 2  15-06-2020
# 3  20-07-2021
# 4  12-11-2019
# 5         NaN
# 6  01-05-2021
# 7  01-05-2021
# 8  20-07-2021

# %%
sm['rank'] = sm['Age'].rank(ascending=False,method = 'dense')
# Out:
# /tmp/ipykernel_1132/946961263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['rank'] = sm['Age'].rank(ascending=False,method = 'dense')

# %%
sm
# Out:
#           City     Name   Age         City Gender              Email  \
# 0     New York    Alice  25.0     New York      F  alice@example.com
# 1        Delhi  Charlie   NaN        Delhi      M    charlie@example
# 2  Los Angeles      Bob  30.0  Los Angeles      M    bob@example.com
# 3        Delhi  Charlie   NaN        Delhi      M    charlie@example
# 4       Mumbai    David  22.0       Mumbai      M  david@example.com
# 5        Delhi      NaN  28.0        Delhi      F     eve@domain.com
# 6     New York    Alice  25.0     New York      F  alice@example.com
# 7     New York    Alice  25.0     New York      F  alice@example.com
# 8        Delhi  Charlie   NaN        Delhi      M    charlie@example
#
#     Join Date  rank
# 0  01-05-2021   3.0
# 1  20-07-2021   NaN
# 2  15-06-2020   1.0
# 3  20-07-2021   NaN
# 4  12-11-2019   4.0
# 5         NaN   2.0
# 6  01-05-2021   3.0
# 7  01-05-2021   3.0
# 8  20-07-2021   NaN
